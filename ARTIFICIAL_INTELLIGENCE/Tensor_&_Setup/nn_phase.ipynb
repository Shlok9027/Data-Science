# %%
import torch 
import torch.nn as nn

layer = nn.Linear(3,2)

x = torch.tensor([1.,2.,3.])


y = layer(x)

print(y)
# Out:
# tensor([-0.1574, -1.1967], grad_fn=<ViewBackward0>)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

# Model
model = MyModel()

# Data
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])

# Loss & Optimizer
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.1)

# Training loop
for epoch in range(10):
    optimizer.zero_grad()

    y_pred = model(x)
    loss = loss_fn(y_pred, y)

    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch + 1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 26.7774
# Epoch 2, Loss: 23.1163
# Epoch 3, Loss: 19.7337
# Epoch 4, Loss: 16.6336
# Epoch 5, Loss: 13.8184
# Epoch 6, Loss: 11.2891
# Epoch 7, Loss: 9.0444
# Epoch 8, Loss: 7.0809
# Epoch 9, Loss: 5.3923
# Epoch 10, Loss: 3.9700

# %%
import torch 
import torch.nn as nn

image = torch.rand(1,1,28,28)

conv = nn.Conv2d(
    in_channels=1,
    out_channels=8,
    kernel_size=3,
    stride=1,
    padding=1
)


output = conv(image)

print('Input Image', image.shape)
print('Output Image' , image.shape)
# Out:
# Input Image torch.Size([1, 1, 28, 28])
# Output Image torch.Size([1, 1, 28, 28])
